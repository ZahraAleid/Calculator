# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahraAleid/Calculator/blob/main/calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Calculator using python


def add(num1,num2):
  print(num1, " + ", num2, " = ",num1+num2)

def sub(num1,num2):
  print(num1, " - ", num2, " = ",num1-num2)

def mult(num1,num2):
  print(num1, " * ", num2, " = ",num1*num2)

def div(num1,num2):
  while True:
    if num2 ==0:
      print("\n You can't divide on zero, choose another number\n")
      while True:
        try:
          num2 = float(input("\n Enter the second number: "))
          break
        except:
          print("\n Please enter a number only.")
    else:
      break

  print(num1, " / ", num2, " = ",num1/num2)




print("Welcome to my calculator \n \n************************")

while True:
  print( "\n Choose Operation: \n  1-Addition \n 2-Subtraction \n 3-Multiplication \n 4-Division \n 5-Exit \n")
  operation= input()

  match operation:
    case "1"|"2"|"3"|"4":
      while True:
        try:
          num1 = float(input("\n Enter the first number: "))
          break
        except:
          print("\n Please enter a number only.")

      while True:
        try:
          num2 = float(input("\n Enter the second number: "))
          break
        except:
          print("\n Please enter a number only.")

      match operation:

        case "1":
          add(num1,num2)
        case "2":
          sub(num1,num2)
        case "3":
          mult(num1,num2)
        case "4":
          div(num1,num2)
    case "5":
      print("\n Good bye ^_^")
      break
    case _:
      print("Please enter a valid number")
# Out:
# Welcome to my calculator
#
# ************************
#
#  Choose Operation:
#   1-Addition
#  2-Subtraction
#  3-Multiplication
#  4-Division
#  5-Exit
#
# 4
#
#  Enter the first number: e
#
#  Please enter a number only.
#
#  Enter the first number: 8
#
#  Enter the second number: 0
#
#  You can't divide on zero, choose another number
#
#
#  Enter the second number: j
#
#  Please enter a number only.
#
#  Enter the second number: 0
#
#  You can't divide on zero, choose another number
#
#
#  Enter the second number: k
#
#  Please enter a number only.
#
#  Enter the second number: 2
# 8.0  /  2.0  =  4.0
#
#  Choose Operation:
#   1-Addition
#  2-Subtraction
#  3-Multiplication
#  4-Division
#  5-Exit
#
# 1
#
#  Enter the first number: 3
#
#  Enter the second number: c
#
#  Please enter a number only.
#
#  Enter the second number: 2
# 3.0  +  2.0  =  5.0
#
#  Choose Operation:
#   1-Addition
#  2-Subtraction
#  3-Multiplication
#  4-Division
#  5-Exit
#
# 2
#
#  Enter the first number: 3.66
#
#  Enter the second number: 2.11
# 3.66  -  2.11  =  1.5500000000000003
#
#  Choose Operation:
#   1-Addition
#  2-Subtraction
#  3-Multiplication
#  4-Division
#  5-Exit
#
# 3
#
#  Enter the first number: 3.6
#
#  Enter the second number: 2.8
# 3.6  *  2.8  =  10.08
#
#  Choose Operation:
#   1-Addition
#  2-Subtraction
#  3-Multiplication
#  4-Division
#  5-Exit
#
# 4
#
#  Enter the first number: 0.11
#
#  Enter the second number: 0.55
# 0.11  /  0.55  =  0.19999999999999998
#
#  Choose Operation:
#   1-Addition
#  2-Subtraction
#  3-Multiplication
#  4-Division
#  5-Exit
#
# 5
#
#  Good bye ^_^
